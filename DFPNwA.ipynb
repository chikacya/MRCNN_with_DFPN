# %% [markdown]
# Load google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# GPU check

# %%
# !nvidia-smi

# %% [markdown]
# Instll requirements

# %%
import os
os.chdir("/content/drive/My Drive/MRCNN_DFPNkA")

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Train

# %%
import os
os.chdir("/content/drive/My Drive/MRCNN_DFPNkA/samples/coco")

# %%
# !python coco.py train --dataset='/content/drive/My Drive/VEDAI_COCO/' --model=coco

# %% [markdown]
# tensorboard

# %%
# !pip uninstall tensorboard
# !pip uninstall tensorboard-plugin-wit
# !pip install tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/content/drive/My Drive/MRCNN_DFPNkA/logs/coco20200514T0230'

# %% [markdown]
# Test

# %%
# !python coco.py evaluate --dataset='/content/drive/My Drive/VEDAI_COCO/' --model='/content/drive/My Drive/MRCNN_DFPNkA/mask_rcnn_dfpn_ka_coco' --limit=200
